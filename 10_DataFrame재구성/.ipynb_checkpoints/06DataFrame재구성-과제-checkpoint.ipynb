# %% [markdown]
# ## 데이터 셋
# - [sample1.csv](https://docs.google.com/spreadsheets/d/1u6v9RclTm7_V-YgSvDT-OFVyHiLgDnXIHyE5iqxQLr0/edit?usp=sharing) - 학업성취도

# %% [markdown]
# ## Pandas참조 + students 데이터프레임 생성

# %%
import pandas as pd

# %%
students = pd.read_csv('sample1.csv')
students
# Out:
#      학생번호  성별  반 부모 학업 성취 석식 신청 선행학습경험  국어점수  영어점수  수학점수
# 0       1  남성  A   일반고등학교     O     있음    68    68    64
# 1       2  여성  D   일반고등학교     X     없음    41    60    55
# 2       3  남성  E       학사     X     없음    59    60    50
# 3       4  남성  B   일반고등학교     O     없음    77    78    68
# 4       5  남성  E    전문학사      O     있음    78    73    68
# ..    ...  .. ..      ...   ...    ...   ...   ...   ...
# 374   375  여성  C   일반고등학교     O     없음    48    63    53
# 375   376  남성  D       학사     O     있음    83    76    81
# 376   377  남성  C   일반고등학교     O     있음    69    75    74
# 377   378  남성  E       학사     X     없음    73    52    54
# 378   379  여성  D       학사     O     없음    43    59    59
#
# [379 rows x 9 columns]

# %% [markdown]
# ## '총점' 열을 데이터프레임에 생성하고 값을 계산

# %%
# 방법 1
students['총점'] = students['국어점수'] + students['영어점수'] + students['수학점수']
students

# %%
# 방법 2
students['총점'] = students[['국어점수', '영어점수', '수학점수']].sum(axis=1)
students
# Out:
#      학생번호  성별  반 부모 학업 성취 석식 신청 선행학습경험  국어점수  영어점수  수학점수   총점
# 0       1  남성  A   일반고등학교     O     있음    68    68    64  200
# 1       2  여성  D   일반고등학교     X     없음    41    60    55  156
# 2       3  남성  E       학사     X     없음    59    60    50  169
# 3       4  남성  B   일반고등학교     O     없음    77    78    68  223
# 4       5  남성  E    전문학사      O     있음    78    73    68  219
# ..    ...  .. ..      ...   ...    ...   ...   ...   ...  ...
# 374   375  여성  C   일반고등학교     O     없음    48    63    53  164
# 375   376  남성  D       학사     O     있음    83    76    81  240
# 376   377  남성  C   일반고등학교     O     있음    69    75    74  218
# 377   378  남성  E       학사     X     없음    73    52    54  179
# 378   379  여성  D       학사     O     없음    43    59    59  161
#
# [379 rows x 10 columns]

# %% [markdown]
# ## 변수에 그룹화 데이터된 데이터 저장
# - '반'과 '석식 신청'을 기준으로

# %%
students_groups = students.groupby(['반', '석식 신청'])

# %%
students_groups

# %%
students_groups.groups
# Out:
# {('A', 'O'): [0, 6, 35, 63, 98, 108, 137, 165, 170, 207, 209, 245, 250, 262, 270, 290, 297, 301, 315, 333], ('A', 'X'): [29, 31, 32, 114, 150, 174, 198, 311, 358, 365], ('B', 'O'): [3, 16, 22, 28, 30, 33, 34, 68, 72, 80, 83, 89, 91, 99, 100, 105, 109, 116, 133, 138, 144, 145, 147, 153, 164, 167, 168, 171, 175, 187, 191, 192, 199, 204, 206, 210, 216, 221, 230, 233, 237, 241, 267, 269, 272, 278, 280, 281, 286, 298, 299, 307, 312, 313, 314, 319, 326, 331, 336, 337, 339, 340, 357, 367, 373], ('B', 'X'): [23, 37, 38, 40, 74, 84, 94, 97, 119, 141, 146, 157, 178, 190, 215, 218, 249, 271, 279, 294, 316, 318, 320, 321], ('C', 'O'): [13, 17, 20, 21, 26, 36, 43, 45, 52, 55, 56, 66, 69, 70, 71, 73, 75, 76, 78, 85, 95, 102, 111, 113, 118, 121, 123, 124, 126, 128, 132, 151, 156, 163, 169, 177, 182, 184, 185, 186, 194, 195, 203, 208, 213, 214, 219, 229, 232, 234, 235, 240, 248, 253, 255, 257, 258, 261, 284, 288, 295, 309, 310, 338, 343, 346, 349, 354, 362, 364, 370, 372, 374, 376], ('C', 'X'): [9, 
# ...

# %%
students_groups.get_group(('A', 'O'))
# Out:
#      학생번호  성별  반 부모 학업 성취 석식 신청 선행학습경험  국어점수  영어점수  수학점수   총점
# 0       1  남성  A   일반고등학교     O     있음    68    68    64  200
# 6       7  여성  A       학사     O     없음    62    59    63  184
# 35     36  여성  A       학사     O     없음    68    74    74  216
# 63     64  남성  A       학사     O     있음    77    82    78  237
# 98     99  남성  A       학사     O     없음    63    50    49  162
# 108   109  남성  A       학사     O     없음    58    40    46  144
# 137   138  남성  A       학사     O     있음    75    83    78  236
# 165   166  남성  A       학사     O     있음    68    74    72  214
# 170   171  여성  A   일반고등학교     O     없음    82    87    85  254
# 207   208  여성  A      석사      O     있음    74    78    84  236
# 209   210  여성  A       학사     O     없음    77    86    84  247
# 245   246  여성  A   일반고등학교     O     없음    40    58    54  152
# 250   251  여성  A   일반고등학교     O     없음    63    69    60  192
# 262   263  여성  A   일반고등학교     O     있음    70    73    80  223
# ...

# %% [markdown]
# ## 반-석식신청으로 그룹화된 학생 그룹의 '총점' 분석
# - agg()를 이용해보자
# - count, median, max, min, mean

# %%
analysis = students_groups.agg({'총점': ['count', 'median', 'max', 'min', 'mean']})
analysis
# Out:
#            총점
#         count median  max  min        mean
# 반 석식 신청
# A O        20  221.5  278  144  214.800000
#   X        10  150.5  225  110  160.600000
# B O        65  202.0  267   98  202.923077
#   X        24  186.5  234   88  177.333333
# C O        74  198.5  293  131  203.472973
#   X        37  184.0  259  102  175.270270
# D O        66  223.5  290  127  220.333333
#   X        30  179.0  284   86  185.333333
# E O        29  243.0  300  144  230.862069
#   X        24  188.0  269  100  188.833333

# %% [markdown]
# ## 총점의 '최저점 - 평균'이 낮은 순으로 정렬하기

# %% [markdown]
# - 석식 신청을 안한 친구들의 성적 최저점이 낮은 편인가?

# %%
analysis['총점'].sort_values(by=['min', 'mean'])
# Out:
#          count  median  max  min        mean
# 반 석식 신청
# D X         30   179.0  284   86  185.333333
# B X         24   186.5  234   88  177.333333
#   O         65   202.0  267   98  202.923077
# E X         24   188.0  269  100  188.833333
# C X         37   184.0  259  102  175.270270
# A X         10   150.5  225  110  160.600000
# D O         66   223.5  290  127  220.333333
# C O         74   198.5  293  131  203.472973
# A O         20   221.5  278  144  214.800000
# E O         29   243.0  300  144  230.862069

# %% [markdown]
# ## 전체 인원에서 석식 여부가 성적에 영향이 있는지 분석해보기
# - 석식 신청으로 그룹화하고
# - count median max min mean std를 확인해보자

# %%
dinner_group = students.groupby('석식 신청')
dinner_group

# %%
analysis = dinner_group.agg({'총점': ['count', 'median', 'max', 'min', 'mean']})
analysis
# Out:
#          총점
#       count median  max min        mean
# 석식 신청
# O       254  214.5  300  98  211.732283
# X       125  185.0  284  86  179.512000

# %% [markdown]
# ## 부모 학업 성취 수준에 따라 성적에 영향이 있는지 분석해보기
# - 학업 성취 수준으로 그룹화하고
# - mean count std median max min 을 확인해보자
# - 평균 높은 순으로 정렬

# %%
parents_group = students.groupby('부모 학업 성취')
parents_group

# %%
parents_group.groups.keys()
# Out:
# dict_keys(['석사 ', '일반고등학교', '전문학사 ', '특수목적고등학교', '학사'])

# %%
parents_analysis = parents_group.agg({'총점': ['mean', 'count', 'std', 'median', 'max', 'min']})

# %%
parents_analysis.sort_values(('총점', 'mean'), ascending=False)
# Out:
#                   총점
#                 mean count        std median  max  min
# 부모 학업 성취
# 석사        221.346154    26  39.744124  225.5  293  119
# 전문학사      212.288462    52  44.363621  201.5  295  111
# 학사        202.214286   154  42.802322  203.5  300   86
# 일반고등학교    194.737288   118  41.617597  195.0  275   88
# 특수목적고등학교  182.931034    29  38.302304  189.0  259   98
